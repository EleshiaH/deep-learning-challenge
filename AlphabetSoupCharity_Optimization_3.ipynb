# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
dropped_df = application_df.drop(columns = (['EIN', 'NAME']))
dropped_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
dropped_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Bin APPLICATION_TYPE and CLASSIFICATION value counts
application_df_counts = dropped_df['APPLICATION_TYPE'].value_counts()
print(application_df_counts)
classification_df = dropped_df['CLASSIFICATION'].value_counts()
print(classification_df)
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Use a cutoff value of 50 for both features, and create a list of application types to be replaced

cutoff_value = 50

application_types_to_replace = application_df_counts[application_df_counts <= cutoff_value].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    dropped_df['APPLICATION_TYPE'] = dropped_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
dropped_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# Other       54
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Use a cutoff value of 50 for both features, and create a list of classifications to be replaced

cutoff_value = 50

classifications_to_replace = classification_df[classification_df <= cutoff_value].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
  dropped_df['CLASSIFICATION'] = dropped_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
binned_df = dropped_df['CLASSIFICATION'].value_counts()
binned_df
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      441
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# Name: CLASSIFICATION, dtype: int64

# %%
copy_df = dropped_df.copy()
copy_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
dropped_copy_df = copy_df.drop(columns = ['STATUS', 'SPECIAL_CONSIDERATIONS'])
dropped_copy_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION     INCOME_AMT   ASK_AMT  IS_SUCCESSFUL
# 0       Association              0      5000              1
# 1      Co-operative         1-9999    108590              1
# 2       Association              0      5000              0
# 3             Trust    10000-24999      6692              1
# 4             Trust  100000-499999    142590              1
# ...             ...            ...       ...            ...
# 34294   Association              0      5000              0
# 34295   Association              0      5000              0
# 34296   Association              0      5000              0
# 34297   Association              0      5000              1
# 34298  Co-operative          1M-5M  36500179              0
#
# [34299 rows x 8 columns]

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dummy_df = pd.get_dummies(dropped_copy_df[['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
       'ORGANIZATION', 'IS_SUCCESSFUL']])
application_dummy_df.sample(10)
# Out:
#        IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 2780               0                       0                     0
# 13252              1                       0                     0
# 33255              0                       0                     0
# 9106               1                       0                     0
# 25244              1                       0                     0
# 9752               0                       0                     0
# 177                1                       0                     0
# 34253              0                       0                     0
# 18446              0                       0                     0
# 13534              1                       0                     0
#
#        APPLICATION_TYPE_T13  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 2780                      0                     0                    1
# 13252                     0                     0                    1
# 33255                     0                     0                    0
# 9106                      0                     0                    1
# 25244                     0                     0                    1
# 9752                      0                     0                    1
# 177                       0                     0                    1
# 34253                     0                     0                    1
# 18446                     0                     0                    1
# 13534                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  \
# 2780                     0                    0                    0
# 13252                    0                    0                    0
# 33255                    0                    1                    0
# 9106                     0                    0                    0
# 25244                    0                    0                    0
# 9752                     0                    0                    0
# 177                      0                    0                    0
# 34253                    0                    0                    0
# 18446                    0                    0                    0
# 13534                    0                    0                    0
#
#        APPLICATION_TYPE_T7  ...  CLASSIFICATION_Other  USE_CASE_CommunityServ  \
# 2780                     0  ...                     0                       0
# 13252                    0  ...                     0                       0
# 33255                    0  ...                     0                       0
# 9106                     0  ...                     0                       0
# 25244                    0  ...                     0                       0
# 9752                     0  ...                     0                       0
# 177                      0  ...                     0                       0
# 34253                    0  ...                     0                       0
# 18446                    0  ...                     0                       0
# 13534                    0  ...                     0                       0
#
#        USE_CASE_Heathcare  USE_CASE_Other  USE_CASE_Preservation  \
# 2780                    0               0                      1
# 13252                   0               0                      1
# 33255                   0               0                      0
# 9106                    0               0                      1
# 25244                   0               0                      1
# 9752                    0               0                      1
# 177                     0               0                      1
# 34253                   0               0                      1
# 18446                   0               0                      1
# 13534                   0               0                      1
#
#        USE_CASE_ProductDev  ORGANIZATION_Association  \
# 2780                     0                         1
# 13252                    0                         0
# 33255                    1                         1
# 9106                     0                         0
# 25244                    0                         0
# 9752                     0                         0
# 177                      0                         0
# 34253                    0                         0
# 18446                    0                         0
# 13534                    0                         0
#
#        ORGANIZATION_Co-operative  ORGANIZATION_Corporation  ORGANIZATION_Trust
# 2780                           0                         0                   0
# 13252                          0                         0                   1
# 33255                          0                         0                   0
# 9106                           0                         0                   1
# 25244                          0                         0                   1
# 9752                           0                         0                   1
# 177                            0                         0                   1
# 34253                          0                         0                   1
# 18446                          0                         0                   1
# 13534                          0                         0                   1
#
# [10 rows x 42 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = application_dummy_df.drop(columns = ['IS_SUCCESSFUL'])

y = application_dummy_df['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
print(X_train.shape)
# Out:
# (25724, 41)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
num_features = 41

model_1 = tf.keras.models.Sequential()

# First hidden layer
model_1.add(tf.keras.layers.Dense(units=20, activation="relu", input_dim = num_features))

# Second hidden layer
model_1.add(tf.keras.layers.Dense(units=20, activation="relu"))

# Output layer
model_1.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
model_1.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 20)                840
#
#  dense_10 (Dense)            (None, 20)                420
#
#  dense_11 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 1,281
# Trainable params: 1,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model_1.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
model_1.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5860 - accuracy: 0.7069
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5620 - accuracy: 0.7255
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5596 - accuracy: 0.7249
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5583 - accuracy: 0.7260
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5575 - accuracy: 0.7257
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5565 - accuracy: 0.7263
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5561 - accuracy: 0.7277
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5553 - accuracy: 0.7274
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5555 - accuracy: 0.7273
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5550 - accuracy: 0.7279
# Epoch 11/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5548 - accuracy: 0.7273
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5549 - accuracy: 0.7270
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5543 - accuracy: 0.7282
# Epoch 14/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5537 - accuracy: 0.7278
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5537 - accuracy: 0.7276
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5539 - accuracy: 0.7285
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5533 - accuracy: 0.7282
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5533 - accuracy: 0.7281
# Epoch 19/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5530 - accuracy: 0.7283
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5528 - accuracy: 0.7280
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5531 - accuracy: 0.7287
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5531 - accuracy: 0.7274
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5524 - accuracy: 0.7290
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5527 - accuracy: 0.7291
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5525 - accuracy: 0.7288
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5521 - accuracy: 0.7294
# Epoch 27/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5525 - accuracy: 0.7286
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5521 - accuracy: 0.7290
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5521 - accuracy: 0.7288
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5520 - accuracy: 0.7285
# Epoch 31/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5519 - accuracy: 0.7289
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5520 - accuracy: 0.7302
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7283
# Epoch 34/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5519 - accuracy: 0.7285
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5516 - accuracy: 0.7292
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7292
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7285
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5515 - accuracy: 0.7285
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7301
# Epoch 40/100
# 713/804 [=========================>....] - ETA: 0s - loss: 0.5512 - accuracy: 0.7296

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = model_1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Export our model to HDF5 file
model_1.save("AlphabetSoupCharity_Optimization_3.h5")
